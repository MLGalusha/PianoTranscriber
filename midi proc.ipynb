# %%
import pretty_midi

# %%
midi = pretty_midi.PrettyMIDI('midis/MIDI-Unprocessed_SMF_02_R1_2004_01-05_ORIG_MID--AUDIO_02_R1_2004_05_Track05_wav.midi')

for instrument in midi.instruments:
    for note in instrument.notes:
        print(f"Note: Start Time = {note.start}, Pitch = {note.pitch}, End Time = {note.end}, Velocity = {note.velocity}")
# Out:
# Note: Start Time = 1.0927083333333334, Pitch = 71, End Time = 1.1895833333333332, Velocity = 60
# Note: Start Time = 1.2791666666666666, Pitch = 55, End Time = 1.496875, Velocity = 44
# Note: Start Time = 1.4635416666666667, Pitch = 59, End Time = 1.6312499999999999, Velocity = 55
# Note: Start Time = 1.6333333333333333, Pitch = 62, End Time = 1.753125, Velocity = 52
# Note: Start Time = 1.2885416666666667, Pitch = 71, End Time = 1.79375, Velocity = 54
# Note: Start Time = 1.7864583333333333, Pitch = 72, End Time = 1.828125, Velocity = 76
# Note: Start Time = 1.8031249999999999, Pitch = 67, End Time = 2.0, Velocity = 56
# Note: Start Time = 1.9833333333333334, Pitch = 74, End Time = 2.0979166666666664, Velocity = 68
# Note: Start Time = 2.0375, Pitch = 72, End Time = 2.10625, Velocity = 77
# Note: Start Time = 2.0979166666666664, Pitch = 74, End Time = 2.1822916666666665, Velocity = 51
# Note: Start Time = 2.171875, Pitch = 67, End Time = 2.2802083333333334, Velocity = 57
# ...
